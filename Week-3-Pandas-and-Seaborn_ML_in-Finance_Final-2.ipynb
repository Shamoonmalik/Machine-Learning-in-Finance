# %% [markdown]
# <html> <h1 style="font-style:bold; color:blue;"> Machine Learning in Finance </h1> </html>

# %% [markdown]
# <html> <h1 style="font-style:italic; color:blue;"> Week-3 </h1> </html>

# %% [markdown]
# # Introduction to Pandas and Seaborn

# %% [markdown]
# ..........................................................![image.png](attachment:c97c0d40-993b-42b5-b634-8244918366df.png)

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# <html> <h2 style="color:blue;"> The first example is the prediction of a client leaving a telecom company </h2> </html>

# %% [markdown]
# ..........................................................![image.png](attachment:980b6f15-530a-4bd9-abe4-cae2b388ed9f.png)

# %%
data = pd.read_csv('telecom_churn.csv')

# %% [markdown]
# ..........................................................![image.png](attachment:4c162e2a-36aa-4d8a-a424-a58590dcb030.png)

# %%
data.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# 1             27.47              195.5              103             16.62
# 2             41.38              121.2              110             10.30
# 3             50.90               61.9               88              5.26
# 4             28.34              148.3              122             12.61
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
# 2                162.6                104                7.32
# 3                196.9                 89                8.86
# 4                186.9                121                8.41
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3               2.70
# 1                13.7                 3               3.70
# 2                12.2                 5               3.29
# 3                 6.6                 7               1.78
# 4                10.1                 3               2.73
#
#    Customer service calls  Churn
# 0                       1  False
# 1                       1  False
# 2                       0  False
# 3                       2  False
# 4                       3  False

# %%
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# 1             27.47              195.5              103             16.62
# 2             41.38              121.2              110             10.30
# 3             50.90               61.9               88              5.26
# 4             28.34              148.3              122             12.61
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
# 2                162.6                104                7.32
# 3                196.9                 89                8.86
# 4                186.9                121                8.41
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3               2.70
# 1                13.7                 3               3.70
# 2                12.2                 5               3.29
# 3                 6.6                 7               1.78
# 4                10.1                 3               2.73
#
#    Customer service calls  Churn
# 0                       1  False
# 1                       1  False
# 2                       0  False
# 3                       2  False
# 4                       3  False

# %% [markdown]
# ..........................................................![image.png](attachment:df165cfb-dc7e-45ff-9afd-0f592654c443.png)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
#  14  Total night charge      3333 non-null   float64
#  15  Total intl minutes      3333 non-null   float64
#  16  Total intl calls        3333 non-null   int64
#  17  Total intl charge       3333 non-null   float64
#  18  Customer service calls  3333 non-null   int64
#  19  Churn                   3333 non-null   bool
# dtypes: bool(1), float64(8), int64(8), object(3)
# memory usage: 498.1+ KB

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
#  14  Total night charge      3333 non-null   float64
#  15  Total intl minutes      3333 non-null   float64
#  16  Total intl calls        3333 non-null   int64
#  17  Total intl charge       3333 non-null   float64
#  18  Customer service calls  3333 non-null   int64
#  19  Churn                   3333 non-null   bool
# dtypes: bool(1), float64(8), int64(8), object(3)
# memory usage: 498.1+ KB

# %% [markdown]
# ..........................................................

# %%
# We have no data gaps (NaN)!
# Churn - a column with the answer (outcome) to whether the client left or not

# %% [markdown]
# <html> <h2 style="color:blue;"> Introduction to Seaborn and Preliminary visual analysis of data </h2> </html>

# %% [markdown]
# ..........................................................![image.png](attachment:76e8386f-e3d0-435e-8c97-9daed238cb8f.png)

# %%
import seaborn as sns

# %%
# If the 'seaborn' library is not installed, install it with the following command:
# (please do this installation only if the previous command has an error message)

# %% [markdown]
# ..........................................................![image.png](attachment:a65d8147-b348-4b98-8386-57412e8da4f6.png)

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\shamoon\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\shamoon\anaconda3\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\shamoon\anaconda3\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\shamoon\anaconda3\lib\site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\shamoon\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\shamoon\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\shamoon\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\shamoon\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\shamoon\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\shamoon\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\shamoon\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\shamoon\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\shamoon\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\shamoon\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\shamoon\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)

# %%
# !pip install seaborn

# if 'seaborn' is installed, ignore this command !
# Out:
# Requirement already satisfied: seaborn in c:\users\vital\anaconda3\lib\site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\vital\anaconda3\lib\site-packages (from seaborn) (1.24.3)
# Requirement already satisfied: pandas>=0.25 in c:\users\vital\anaconda3\lib\site-packages (from seaborn) (2.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\vital\anaconda3\lib\site-packages (from seaborn) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vital\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\vital\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vital\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\vital\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\vital\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\vital\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\vital\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vital\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vital\anaconda3\lib\site-packages (from pandas>=0.25->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\vital\anaconda3\lib\site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\vital\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)

# %% [markdown]
# ..........................................................![image.png](attachment:10b72bb3-fbb7-4026-a154-bc0b58020796.png)

# %%
print(sns.__version__)
# Out:
# 0.13.2

# %%
# Out:
# 0.13.2

# %% [markdown]
# ..........................................................![image.png](attachment:2668e90a-eb41-4359-9e88-4f22dc8ec163.png)

# %%
# %matplotlib inline

# %% [markdown]
# <html> <h3 style="color:blue;"> Quantitative Features Analysis </h3> </html>

# %% [markdown]
# ..........................................................![image.png](attachment:2c20bc06-d5c9-459a-ada3-2447be3d7214.png)

# %%
data['Total day minutes'].hist()
# Out:
# <Axes: >

# %%
# Plot histogram of 'Total day minutes'
data['Total day minutes'].hist()
plt.xlabel('Total Day Minutes')
plt.ylabel('Frequency')
plt.title('Histogram of Total Day Minutes')
plt.show()

# %% [markdown]
# ..........................................................![image.png](attachment:afa11298-a6db-467c-8427-a3434bb6f028.png)

# %%
data['Total day minutes'].hist();

# %% [markdown]
# ..........................................................![image.png](attachment:30d5e8f9-5243-41c8-a8e4-50d6d831517b.png)

# %%
# Box plot for 'Total day minutes' with y-axis
sns.boxplot(y=data['Total day minutes'])
plt.ylabel('Total Day Minutes')
plt.title('Box Plot of Total Day Minutes')
plt.show()

# %% [markdown]
# ..........................................................![image.png](attachment:1916f4a6-2d8f-4d6f-923a-812d26b21b44.png)

# %%
# Plot boxplot of 'Total day minutes'
sns.boxplot(x=data['Total day minutes'], orient="h")
plt.xlabel('Total Day Minutes')
plt.title('Box Plot of Total Day Minutes')
plt.show()

# %% [markdown]
# 1.png![image.png](attachment:image.png)

# %% [markdown]
# <html> <h3 style="color:blue;"> Categorical Features Analysis (including Binary Features) </h3> </html>

# %%
# We have a categorical feature: US State
# and two Binary features: 'International plan' and 'Voice mail plan'

# %% [markdown]
# ..........................................................![image.png](attachment:1b06e4d5-bec0-417f-a0e7-b3898faab5d5.png)

# %%
data['State'].value_counts().head
# Out:
# <bound method NDFrame.head of State
# WV    106
# MN     84
# NY     83
# AL     80
# WI     78
# OH     78
# OR     78
# WY     77
# VA     77
# CT     74
# MI     73
# ID     73
# VT     73
# TX     72
# UT     72
# IN     71
# MD     70
# KS     70
# NC     68
# NJ     68
# MT     68
# CO     66
# NV     66
# WA     66
# RI     65
# MA     65
# MS     65
# AZ     64
# FL     63
# MO     63
# NM     62
# ME     62
# ND     62
# NE     61
# OK     61
# DE     61
# SC     60
# SD     60
# KY     59
# IL     58
# NH     56
# AR     55
# GA     54
# DC     54
# HI     53
# TN     53
# AK     52
# LA     51
# PA     45
# IA     44
# CA     34
# Name: count, dtype: int64>

# %%
# Out:
# State
# WV    106
# MN     84
# NY     83
# AL     80
# WI     78
# Name: count, dtype: int64

# %% [markdown]
# ..........................................................![image.png](attachment:0954011c-8f72-4c9e-80f6-2cfe2bc1bcae.png)

# %%
data['Churn'].value_counts()
# Out:
# Churn
# False    2850
# True      483
# Name: count, dtype: int64

# %%
# Out:
# Churn
# False    2850
# True      483
# Name: count, dtype: int64

# %%
# How many clients have left this company? Print the number.

# %%
# Count of clients who have churned
clients_left = data['Churn'].value_counts()[True]

# Print the number of clients who have left
print(f"Number of clients who have left the company: {clients_left}")
# Out:
# Number of clients who have left the company: 483

# %% [markdown]
# ..........................................................![image.png](attachment:c7248d69-7c91-428d-a80f-165ead6983f8.png)

# %%
# Count plot for 'Churn'
sns.countplot(x='Churn', data=data)
plt.xlabel('Churn')
plt.ylabel('Number of Clients')
plt.title('Count of Clients by Churn Status')
plt.xticks(ticks=[0, 1], labels=['Not Churned', 'Churned'])  # Optional: Customize x-axis labels
plt.show()

# %% [markdown]
# ..........................................................![image.png](attachment:a309a598-7f6f-4341-a134-5ec16ab7b5d5.png)

# %%
sns.countplot(x=data['Churn'], palette = "Set2")
# Out:
# C:\Users\SHAMOON\AppData\Local\Temp\ipykernel_7564\2396949198.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data['Churn'], palette = "Set2")
# <Axes: xlabel='Churn', ylabel='count'>

# %%
# Out:
# C:\Users\vital\AppData\Local\Temp\ipykernel_27036\3744238448.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data['Churn'], palette = "Set2");

# %% [markdown]
# ..........................................................![image.png](attachment:a8e0fd8d-f4b7-43e1-b663-87e265afad20.png)

# %%
import warnings as warn
warn.filterwarnings('ignore')

# %% [markdown]
# ..........................................................![image.png](attachment:d4f8e3b0-6174-4873-84e7-3126be90e9cf.png)

# %%
sns.countplot(x=data['Churn'], palette = "Set2")
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %%
sns.countplot(x=data['Churn'], palette = "Set3")
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %% [markdown]
# ..........................................................![image.png](attachment:d378dafa-f147-4126-b072-5b37ee91012a.png)

# %%
data['State'].value_counts().head().index
# Out:
# Index(['WV', 'MN', 'NY', 'AL', 'WI'], dtype='object', name='State')

# %% [markdown]
# ![image.png](attachment:5536c0df-7147-4eab-b5b1-ffe2b4c1d246.png)

# %%
data['State'].value_counts()
data['State'].value_counts().head()
data['State'].value_counts().head().index
# Out:
# Index(['WV', 'MN', 'NY', 'AL', 'WI'], dtype='object', name='State')

# %% [markdown]
# ..........................................................![image.png](attachment:35805e7e-c3f2-49f7-97f4-0c0bd7e9cf2e.png)

# %%
data1 = data[data['State'].isin(data['State'].value_counts().head().index)]
data1.head(8)
# Out:
#    State  Account length  Area code International plan Voice mail plan  \
# 5     AL             118        510                Yes              No
# 9     WV             141        415                Yes             Yes
# 15    NY             161        415                 No              No
# 44    WI              64        510                 No              No
# 58    WI              68        415                 No              No
# 62    MN              74        510                 No             Yes
# 67    MN             113        408                Yes              No
# 71    MN             162        510                 No             Yes
#
#     Number vmail messages  Total day minutes  Total day calls  \
# 5                       0              223.4               98
# 9                      37              258.6               84
# 15                      0              332.9               67
# 44                      0              154.0               67
# 58                      0              148.8               70
# 62                     33              193.7               91
# 67                      0              125.2               93
# 71                     46              224.9               97
#
#     Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 5              37.98              220.6              101             18.75
# 9              43.96              222.0              111             18.87
# 15             56.59              317.8               97             27.01
# 44             26.18              225.8              118             19.19
# 58             25.30              246.5              164             20.95
# 62             32.93              246.1               96             20.92
# 67             21.28              206.4              119             17.54
# 71             38.23              188.2               84             16.00
#
#     Total night minutes  Total night calls  Total night charge  \
# 5                 203.9                118                9.18
# 9                 326.4                 97               14.69
# 15                160.6                128                7.23
# 44                265.3                 86               11.94
# 58                129.8                103                5.84
# 62                138.0                 92                6.21
# 67                129.3                139                5.82
# 71                254.6                 61               11.46
#
#     Total intl minutes  Total intl calls  Total intl charge  \
# 5                  6.3                 6               1.70
# 9                 11.2                 5               3.02
# 15                 5.4                 9               1.46
# 44                 3.5                 3               0.95
# 58                12.1                 3               3.27
# 62                14.6                 3               3.94
# 67                 8.3                 8               2.24
# 71                12.1                 2               3.27
#
#     Customer service calls  Churn
# 5                        0  False
# 9                        0  False
# 15                       4   True
# 44                       1  False
# 58                       3  False
# 62                       2  False
# 67                       0  False
# 71                       0  False

# %%
# Out:
#    State  Account length  Area code International plan Voice mail plan  \
# 5     AL             118        510                Yes              No
# 9     WV             141        415                Yes             Yes
# 15    NY             161        415                 No              No
# 44    WI              64        510                 No              No
# 58    WI              68        415                 No              No
# 62    MN              74        510                 No             Yes
# 67    MN             113        408                Yes              No
# 71    MN             162        510                 No             Yes
#
#     Number vmail messages  Total day minutes  Total day calls  \
# 5                       0              223.4               98
# 9                      37              258.6               84
# 15                      0              332.9               67
# 44                      0              154.0               67
# 58                      0              148.8               70
# 62                     33              193.7               91
# 67                      0              125.2               93
# 71                     46              224.9               97
#
#     Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 5              37.98              220.6              101             18.75
# 9              43.96              222.0              111             18.87
# 15             56.59              317.8               97             27.01
# 44             26.18              225.8              118             19.19
# 58             25.30              246.5              164             20.95
# 62             32.93              246.1               96             20.92
# 67             21.28              206.4              119             17.54
# 71             38.23              188.2               84             16.00
#
#     Total night minutes  Total night calls  Total night charge  \
# 5                 203.9                118                9.18
# 9                 326.4                 97               14.69
# 15                160.6                128                7.23
# 44                265.3                 86               11.94
# 58                129.8                103                5.84
# 62                138.0                 92                6.21
# 67                129.3                139                5.82
# 71                254.6                 61               11.46
#
#     Total intl minutes  Total intl calls  Total intl charge  \
# 5                  6.3                 6               1.70
# 9                 11.2                 5               3.02
# 15                 5.4                 9               1.46
# 44                 3.5                 3               0.95
# 58                12.1                 3               3.27
# 62                14.6                 3               3.94
# 67                 8.3                 8               2.24
# 71                12.1                 2               3.27
#
#     Customer service calls  Churn
# 5                        0  False
# 9                        0  False
# 15                       4   True
# 44                       1  False
# 58                       3  False
# 62                       2  False
# 67                       0  False
# 71                       0  False

# %% [markdown]
# ..........................................................![image.png](attachment:fea7f3cf-1434-4068-9443-df6e6d52f39e.png)

# %%
data1['State'].value_counts()
# Out:
# State
# WV    106
# MN     84
# NY     83
# AL     80
# WI     78
# Name: count, dtype: int64

# %%
# Out:
# State
# WV    106
# MN     84
# NY     83
# AL     80
# WI     78
# Name: count, dtype: int64

# %% [markdown]
# ..........................................................![image.png](attachment:d54471cb-97db-4e8d-b923-2d8351636b49.png)

# %%
# Count plot for 'State'
sns.countplot(x=data1['State'], palette="Set1")
plt.xlabel('State')
plt.ylabel('Count')

# Limit y-axis value to 100
plt.ylim(0, 110)

plt.show()

# %% [markdown]
# <html> <h3 style="color:blue;"> Features Interactions </h3> </html>

# %% [markdown]
# #### Quantitative -> Quantitative

# %% [markdown]
# ..........................................................![image.png](attachment:e2d21b5e-0d56-4393-9e22-32eb0028df43.png)

# %%
data.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %% [markdown]
# ..........................................................![image.png](attachment:aedb3b0c-5e2a-4491-b7a0-8a100363de66.png)

# %%
Feat = [x for x in data.columns if 'charge' in x]
Feat
# Out:
# ['Total day charge',
#  'Total eve charge',
#  'Total night charge',
#  'Total intl charge']

# %%
# Out:
# ['Total day charge',
#  'Total eve charge',
#  'Total night charge',
#  'Total intl charge']

# %% [markdown]
# ..........................................................![image.png](attachment:0dbeb4c6-661a-4a62-88fb-01f64a7bce62.png)

# %%
# Create histogram for the specified feature
data[Feat].hist()
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# <html> <h3 style="font-style:italic; color:red;"> Save your file until start next cell-code </h3> </html>

# %% [markdown]
# ..........................................................![image.png](attachment:7ea46c47-9870-4814-b0b3-f143e7bddbe6.png)

# %%
# Create a pairplot for the selected features
sns.pairplot(data[Feat])
plt.show()

# %% [markdown]
# <html> <h3 style="font-style:italic; color:red;"> Save your file until start next cell-code </h3> </html>

# %%
# Create a PairGrid
g = sns.PairGrid(data, vars=Feat)

# Map the upper triangle to scatter plots
g.map_upper(sns.scatterplot)

# Map the diagonal to histograms with KDE
g.map_diag(sns.histplot, kde=True)

# Map the lower triangle to KDE plots
g.map_lower(sns.kdeplot)

# Add legend for the hue
g.add_legend()

# Show the plot
plt.show()

# %%
# It looks like a normal distribution which is not interesting for a data scientist

# %%
# The pairwise relationships below demonstrate more stronger relationships
# You do not have to type any code in the cell

# %% [markdown]
# ![image.png](attachment:187090eb-a663-44e2-b61b-c46c3d155a98.png)

# %% [markdown]
# ..........................................................![image.png](attachment:8703ca29-2b16-466d-a0bc-eaafe23d20c1.png)

# %%
plt.scatter(data['Total eve charge'], data['Total intl charge']);
plt.xlabel('Evening charge');
plt.ylabel('International charge');

# %% [markdown]
# ..........................................................![image.png](attachment:13bc81ef-a395-4dd4-8d9a-000915d63218.png)

# %%
plt.scatter(data['Total eve charge'], data['Total intl charge' ],
color='orange');
plt.xlabel('Evening charge');
plt.ylabel('International charge');

# %% [markdown]
# <html> <h4 style="color:blue;"> Draw a bicolour diagram (including Binary Features) </h4> </html>

# %% [markdown]
# ..........................................................![image.png](attachment:be36edfb-2a84-45ed-a0d9-e3cc54b86f1b.png)

# %%
Clr = data['Churn'].map({False: 'blue', True: 'orange'} )
Clr.head()
# Out:
# 0    blue
# 1    blue
# 2    blue
# 3    blue
# 4    blue
# Name: Churn, dtype: object

# %%
# Out:
# 0    blue
# 1    blue
# 2    blue
# 3    blue
# 4    blue
# Name: Churn, dtype: object

# %% [markdown]
# ..........................................................![image.png](attachment:c7c806cd-f4ec-4457-a347-48afeecef444.png)

# %%
fig = plt.figure(figsize=(11, 7))

plt.scatter(data['Total eve charge'], data['Total intl charge'], color = Clr );
plt.xlabel('Evening charge');
plt.ylabel('International charge');

# %% [markdown]
# ..........................................................![image.png](attachment:94973576-0108-4913-aa87-bd55cc3ca8a9.png)

# %%
fig = plt.figure(figsize=(11, 7))

plt.scatter(data['Total eve charge' ], data['Total intl charge'], color = Clr,
            s=(data['Total intl charge'] + 0.05) );
plt.xlabel('Evening charge');
plt.ylabel('International charge');

# %% [markdown]
# <html> <h3 style="color:blue;"> Quantitative vs Categorical (Binary) </h3> </html>

# %% [markdown]
# ..........................................................![image.png](attachment:4883f1ea-4a7d-4e8b-b14b-3552f3a7da66.png)

# %%
sns. boxplot(x = 'Churn', y = 'Total day minutes', data=data, palette = "Set1");

# %%
# The medians are very different in these features.
# Therefore, clients who left had a lot of talk minutes!

# %% [markdown]
# ..........................................................![image.png](attachment:8a5b2e06-4ec5-4b71-bc7f-ca83ac83bc3d.png)

# %%
fig = plt.figure(figsize=(13, 5))
sns. boxplot(x = 'State', y = 'Total day minutes', data=data, palette = "Set2");

# %%
# It looks like not informative

# %% [markdown]
# <html> <h3 style="color:blue;"> Interaction of Two Categorical (Binary) Features </h3> </html>

# %% [markdown]
# ..........................................................![image.png](attachment:93adb583-2fa7-4cae-81a1-49bfffeb7b41.png)

# %%
pd. crosstab(data['Churn'], data['International plan'])
# Out:
# International plan    No  Yes
# Churn
# False               2664  186
# True                 346  137

# %%
# Out:
# International plan    No  Yes
# Churn
# False               2664  186
# True                 346  137

# %% [markdown]
# ..........................................................![image.png](attachment:bfd69a87-ad43-40df-9256-1875f8972947.png)

# %%
sns.countplot(x = 'International plan', hue = 'Churn', data = data);

# %%
# It is an interesting result - connecting to international roaming dramatically 
# increases the probability of a client leaving !

# %% [markdown]
# ..........................................................![image.png](attachment:a5e9ef9d-0930-415a-be5c-4bd72bb9a837.png)

# %%
sns. countplot(x = 'Customer service calls', hue = 'Churn', data = data);

# %%
# One more interesting result.
# If a customer calls the service centre 4(four) or more times, then they are ready to leave!

# %% [markdown]
# <html> <h3 style="color:blue;"> Correlation Matrix and Heat Map </h3> </html>

# %% [markdown]
# ..........................................................![image.png](attachment:b34d3bd4-b3de-471a-b1a9-041ee7a52826.png)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
#  14  Total night charge      3333 non-null   float64
#  15  Total intl minutes      3333 non-null   float64
#  16  Total intl calls        3333 non-null   int64
#  17  Total intl charge       3333 non-null   float64
#  18  Customer service calls  3333 non-null   int64
#  19  Churn                   3333 non-null   bool
# dtypes: bool(1), float64(8), int64(8), object(3)
# memory usage: 498.1+ KB

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
#  14  Total night charge      3333 non-null   float64
#  15  Total intl minutes      3333 non-null   float64
#  16  Total intl calls        3333 non-null   int64
#  17  Total intl charge       3333 non-null   float64
#  18  Customer service calls  3333 non-null   int64
#  19  Churn                   3333 non-null   bool
# dtypes: bool(1), float64(8), int64(8), object(3)
# memory usage: 498.1+ KB

# %% [markdown]
# ..........................................................![image.png](attachment:bf99f55b-2e40-4ce4-8605-c4190f674096.png)

# %%
data2 = data.drop(['State'], axis = 1)

# %% [markdown]
# ..........................................................![image.png](attachment:5b775714-9053-4c26-93fb-03137651b23c.png)

# %%
d = {"No": 0, "Yes": 1}
data2 = data2.replace({'International plan': d})
data2 = data2.replace({'Voice mail plan':d})

# %% [markdown]
# ..........................................................![image.png](attachment:868021ec-675a-4549-bf46-fb093e359f46.png)

# %%
data2['Churn'] = data2['Churn'].astype('int8')

# %% [markdown]
# ..........................................................![image.png](attachment:246a5086-d2f6-44ad-b014-4b27fc2f701b.png)

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Account length          3333 non-null   int64
#  1   Area code               3333 non-null   int64
#  2   International plan      3333 non-null   int64
#  3   Voice mail plan         3333 non-null   int64
#  4   Number vmail messages   3333 non-null   int64
#  5   Total day minutes       3333 non-null   float64
#  6   Total day calls         3333 non-null   int64
#  7   Total day charge        3333 non-null   float64
#  8   Total eve minutes       3333 non-null   float64
#  9   Total eve calls         3333 non-null   int64
#  10  Total eve charge        3333 non-null   float64
#  11  Total night minutes     3333 non-null   float64
#  12  Total night calls       3333 non-null   int64
#  13  Total night charge      3333 non-null   float64
#  14  Total intl minutes      3333 non-null   float64
#  15  Total intl calls        3333 non-null   int64
#  16  Total intl charge       3333 non-null   float64
#  17  Customer service calls  3333 non-null   int64
#  18  Churn                   3333 non-null   bool
# dtypes: bool(1), float64(8), int64(10)
# memory usage: 472.1 KB

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Account length          3333 non-null   int64
#  1   Area code               3333 non-null   int64
#  2   International plan      3333 non-null   int64
#  3   Voice mail plan         3333 non-null   int64
#  4   Number vmail messages   3333 non-null   int64
#  5   Total day minutes       3333 non-null   float64
#  6   Total day calls         3333 non-null   int64
#  7   Total day charge        3333 non-null   float64
#  8   Total eve minutes       3333 non-null   float64
#  9   Total eve calls         3333 non-null   int64
#  10  Total eve charge        3333 non-null   float64
#  11  Total night minutes     3333 non-null   float64
#  12  Total night calls       3333 non-null   int64
#  13  Total night charge      3333 non-null   float64
#  14  Total intl minutes      3333 non-null   float64
#  15  Total intl calls        3333 non-null   int64
#  16  Total intl charge       3333 non-null   float64
#  17  Customer service calls  3333 non-null   int64
#  18  Churn                   3333 non-null   int8
# dtypes: float64(8), int64(10), int8(1)
# memory usage: 472.1 KB

# %%
# Now we have only digital data, therefore we can build a correlation matrix

# %% [markdown]
# ..........................................................![image.png](attachment:0a791f74-22dd-4def-a6cd-2cdf95247999.png)

# %%
correlation_matrix = data2. corr()
correlation_matrix
# Out:
#                         Account length  Area code  International plan  \
# Account length                1.000000  -0.012463            0.024735
# Area code                    -0.012463   1.000000            0.048551
# International plan            0.024735   0.048551            1.000000
# Voice mail plan               0.002918  -0.000747            0.006006
# Number vmail messages        -0.004628  -0.001994            0.008745
# Total day minutes             0.006216  -0.008264            0.049396
# Total day calls               0.038470  -0.009646            0.003755
# Total day charge              0.006214  -0.008264            0.049398
# Total eve minutes            -0.006757   0.003580            0.019100
# Total eve calls               0.019260  -0.011886            0.006114
# Total eve charge             -0.006745   0.003607            0.019106
# Total night minutes          -0.008955  -0.005825           -0.028905
# Total night calls            -0.013176   0.016522            0.012451
# Total night charge           -0.008960  -0.005845           -0.028913
# Total intl minutes            0.009514  -0.018288            0.045871
# Total intl calls              0.020661  -0.024179            0.017366
# Total intl charge             0.009546  -0.018395            0.045780
# Customer service calls       -0.003796   0.027572           -0.024522
# Churn                         0.016541   0.006174            0.259852
#
#                         Voice mail plan  Number vmail messages  \
# Account length                 0.002918              -0.004628
# Area code                     -0.000747              -0.001994
# International plan             0.006006               0.008745
# Voice mail plan                1.000000               0.956927
# Number vmail messages          0.956927               1.000000
# Total day minutes             -0.001684               0.000778
# Total day calls               -0.011086              -0.009548
# Total day charge              -0.001686               0.000776
# Total eve minutes              0.021545               0.017562
# Total eve calls               -0.006444              -0.005864
# Total eve charge               0.021559               0.017578
# Total night minutes            0.006079               0.007681
# Total night calls              0.015553               0.007123
# Total night charge             0.006064               0.007663
# Total intl minutes            -0.001318               0.002856
# Total intl calls               0.007618               0.013957
# Total intl charge             -0.001276               0.002884
# Customer service calls        -0.017824              -0.013263
# Churn                         -0.102148              -0.089728
#
#                         Total day minutes  Total day calls  Total day charge  \
# Account length                   0.006216         0.038470          0.006214
# Area code                       -0.008264        -0.009646         -0.008264
# International plan               0.049396         0.003755          0.049398
# Voice mail plan                 -0.001684        -0.011086         -0.001686
# Number vmail messages            0.000778        -0.009548          0.000776
# Total day minutes                1.000000         0.006750          1.000000
# Total day calls                  0.006750         1.000000          0.006753
# Total day charge                 1.000000         0.006753          1.000000
# Total eve minutes                0.007043        -0.021451          0.007050
# Total eve calls                  0.015769         0.006462          0.015769
# Total eve charge                 0.007029        -0.021449          0.007036
# Total night minutes              0.004323         0.022938          0.004324
# Total night calls                0.022972        -0.019557          0.022972
# Total night charge               0.004300         0.022927          0.004301
# Total intl minutes              -0.010155         0.021565         -0.010157
# Total intl calls                 0.008033         0.004574          0.008032
# Total intl charge               -0.010092         0.021666         -0.010094
# Customer service calls          -0.013423        -0.018942         -0.013427
# Churn                            0.205151         0.018459          0.205151
#
#                         Total eve minutes  Total eve calls  Total eve charge  \
# Account length                  -0.006757         0.019260         -0.006745
# Area code                        0.003580        -0.011886          0.003607
# International plan               0.019100         0.006114          0.019106
# Voice mail plan                  0.021545        -0.006444          0.021559
# Number vmail messages            0.017562        -0.005864          0.017578
# Total day minutes                0.007043         0.015769          0.007029
# Total day calls                 -0.021451         0.006462         -0.021449
# Total day charge                 0.007050         0.015769          0.007036
# Total eve minutes                1.000000        -0.011430          1.000000
# Total eve calls                 -0.011430         1.000000         -0.011423
# Total eve charge                 1.000000        -0.011423          1.000000
# Total night minutes             -0.012584        -0.002093         -0.012592
# Total night calls                0.007586         0.007710          0.007596
# Total night charge              -0.012593        -0.002056         -0.012601
# Total intl minutes              -0.011035         0.008703         -0.011043
# Total intl calls                 0.002541         0.017434          0.002541
# Total intl charge               -0.011067         0.008674         -0.011074
# Customer service calls          -0.012985         0.002423         -0.012987
# Churn                            0.092796         0.009233          0.092786
#
#                         Total night minutes  Total night calls  \
# Account length                    -0.008955          -0.013176
# Area code                         -0.005825           0.016522
# International plan                -0.028905           0.012451
# Voice mail plan                    0.006079           0.015553
# Number vmail messages              0.007681           0.007123
# Total day minutes                  0.004323           0.022972
# Total day calls                    0.022938          -0.019557
# Total day charge                   0.004324           0.022972
# Total eve minutes                 -0.012584           0.007586
# Total eve calls                   -0.002093           0.007710
# Total eve charge                  -0.012592           0.007596
# Total night minutes                1.000000           0.011204
# Total night calls                  0.011204           1.000000
# Total night charge                 0.999999           0.011188
# Total intl minutes                -0.015207          -0.013605
# Total intl calls                  -0.012353           0.000305
# Total intl charge                 -0.015180          -0.013630
# Customer service calls            -0.009288          -0.012802
# Churn                              0.035493           0.006141
#
#                         Total night charge  Total intl minutes  \
# Account length                   -0.008960            0.009514
# Area code                        -0.005845           -0.018288
# International plan               -0.028913            0.045871
# Voice mail plan                   0.006064           -0.001318
# Number vmail messages             0.007663            0.002856
# Total day minutes                 0.004300           -0.010155
# Total day calls                   0.022927            0.021565
# Total day charge                  0.004301           -0.010157
# Total eve minutes                -0.012593           -0.011035
# Total eve calls                  -0.002056            0.008703
# Total eve charge                 -0.012601           -0.011043
# Total night minutes               0.999999           -0.015207
# Total night calls                 0.011188           -0.013605
# Total night charge                1.000000           -0.015214
# Total intl minutes               -0.015214            1.000000
# Total intl calls                 -0.012329            0.032304
# Total intl charge                -0.015186            0.999993
# Customer service calls           -0.009277           -0.009640
# Churn                             0.035496            0.068239
#
#                         Total intl calls  Total intl charge  \
# Account length                  0.020661           0.009546
# Area code                      -0.024179          -0.018395
# International plan              0.017366           0.045780
# Voice mail plan                 0.007618          -0.001276
# Number vmail messages           0.013957           0.002884
# Total day minutes               0.008033          -0.010092
# Total day calls                 0.004574           0.021666
# Total day charge                0.008032          -0.010094
# Total eve minutes               0.002541          -0.011067
# Total eve calls                 0.017434           0.008674
# Total eve charge                0.002541          -0.011074
# Total night minutes            -0.012353          -0.015180
# Total night calls               0.000305          -0.013630
# Total night charge             -0.012329          -0.015186
# Total intl minutes              0.032304           0.999993
# Total intl calls                1.000000           0.032372
# Total intl charge               0.032372           1.000000
# Customer service calls         -0.017561          -0.009675
# Churn                          -0.052844           0.068259
#
#                         Customer service calls     Churn
# Account length                       -0.003796  0.016541
# Area code                             0.027572  0.006174
# International plan                   -0.024522  0.259852
# Voice mail plan                      -0.017824 -0.102148
# Number vmail messages                -0.013263 -0.089728
# Total day minutes                    -0.013423  0.205151
# Total day calls                      -0.018942  0.018459
# Total day charge                     -0.013427  0.205151
# Total eve minutes                    -0.012985  0.092796
# Total eve calls                       0.002423  0.009233
# Total eve charge                     -0.012987  0.092786
# Total night minutes                  -0.009288  0.035493
# Total night calls                    -0.012802  0.006141
# Total night charge                   -0.009277  0.035496
# Total intl minutes                   -0.009640  0.068239
# Total intl calls                     -0.017561 -0.052844
# Total intl charge                    -0.009675  0.068259
# Customer service calls                1.000000  0.208750
# Churn                                 0.208750  1.000000

# %%
# Out:
#                         Account length  Area code  International plan  \
# Account length                1.000000  -0.012463            0.024735
# Area code                    -0.012463   1.000000            0.048551
# International plan            0.024735   0.048551            1.000000
# Voice mail plan               0.002918  -0.000747            0.006006
# Number vmail messages        -0.004628  -0.001994            0.008745
# Total day minutes             0.006216  -0.008264            0.049396
# Total day calls               0.038470  -0.009646            0.003755
# Total day charge              0.006214  -0.008264            0.049398
# Total eve minutes            -0.006757   0.003580            0.019100
# Total eve calls               0.019260  -0.011886            0.006114
# Total eve charge             -0.006745   0.003607            0.019106
# Total night minutes          -0.008955  -0.005825           -0.028905
# Total night calls            -0.013176   0.016522            0.012451
# Total night charge           -0.008960  -0.005845           -0.028913
# Total intl minutes            0.009514  -0.018288            0.045871
# Total intl calls              0.020661  -0.024179            0.017366
# Total intl charge             0.009546  -0.018395            0.045780
# Customer service calls       -0.003796   0.027572           -0.024522
# Churn                         0.016541   0.006174            0.259852
#
#                         Voice mail plan  Number vmail messages  \
# Account length                 0.002918              -0.004628
# Area code                     -0.000747              -0.001994
# International plan             0.006006               0.008745
# Voice mail plan                1.000000               0.956927
# Number vmail messages          0.956927               1.000000
# Total day minutes             -0.001684               0.000778
# Total day calls               -0.011086              -0.009548
# Total day charge              -0.001686               0.000776
# Total eve minutes              0.021545               0.017562
# Total eve calls               -0.006444              -0.005864
# Total eve charge               0.021559               0.017578
# Total night minutes            0.006079               0.007681
# Total night calls              0.015553               0.007123
# Total night charge             0.006064               0.007663
# Total intl minutes            -0.001318               0.002856
# Total intl calls               0.007618               0.013957
# Total intl charge             -0.001276               0.002884
# Customer service calls        -0.017824              -0.013263
# Churn                         -0.102148              -0.089728
#
#                         Total day minutes  Total day calls  Total day charge  \
# Account length                   0.006216         0.038470          0.006214
# Area code                       -0.008264        -0.009646         -0.008264
# International plan               0.049396         0.003755          0.049398
# Voice mail plan                 -0.001684        -0.011086         -0.001686
# Number vmail messages            0.000778        -0.009548          0.000776
# Total day minutes                1.000000         0.006750          1.000000
# Total day calls                  0.006750         1.000000          0.006753
# Total day charge                 1.000000         0.006753          1.000000
# Total eve minutes                0.007043        -0.021451          0.007050
# Total eve calls                  0.015769         0.006462          0.015769
# Total eve charge                 0.007029        -0.021449          0.007036
# Total night minutes              0.004323         0.022938          0.004324
# Total night calls                0.022972        -0.019557          0.022972
# Total night charge               0.004300         0.022927          0.004301
# Total intl minutes              -0.010155         0.021565         -0.010157
# Total intl calls                 0.008033         0.004574          0.008032
# Total intl charge               -0.010092         0.021666         -0.010094
# Customer service calls          -0.013423        -0.018942         -0.013427
# Churn                            0.205151         0.018459          0.205151
#
#                         Total eve minutes  Total eve calls  Total eve charge  \
# Account length                  -0.006757         0.019260         -0.006745
# Area code                        0.003580        -0.011886          0.003607
# International plan               0.019100         0.006114          0.019106
# Voice mail plan                  0.021545        -0.006444          0.021559
# Number vmail messages            0.017562        -0.005864          0.017578
# Total day minutes                0.007043         0.015769          0.007029
# Total day calls                 -0.021451         0.006462         -0.021449
# Total day charge                 0.007050         0.015769          0.007036
# Total eve minutes                1.000000        -0.011430          1.000000
# Total eve calls                 -0.011430         1.000000         -0.011423
# Total eve charge                 1.000000        -0.011423          1.000000
# Total night minutes             -0.012584        -0.002093         -0.012592
# Total night calls                0.007586         0.007710          0.007596
# Total night charge              -0.012593        -0.002056         -0.012601
# Total intl minutes              -0.011035         0.008703         -0.011043
# Total intl calls                 0.002541         0.017434          0.002541
# Total intl charge               -0.011067         0.008674         -0.011074
# Customer service calls          -0.012985         0.002423         -0.012987
# Churn                            0.092796         0.009233          0.092786
#
#                         Total night minutes  Total night calls  \
# Account length                    -0.008955          -0.013176
# Area code                         -0.005825           0.016522
# International plan                -0.028905           0.012451
# Voice mail plan                    0.006079           0.015553
# Number vmail messages              0.007681           0.007123
# Total day minutes                  0.004323           0.022972
# Total day calls                    0.022938          -0.019557
# Total day charge                   0.004324           0.022972
# Total eve minutes                 -0.012584           0.007586
# Total eve calls                   -0.002093           0.007710
# Total eve charge                  -0.012592           0.007596
# Total night minutes                1.000000           0.011204
# Total night calls                  0.011204           1.000000
# Total night charge                 0.999999           0.011188
# Total intl minutes                -0.015207          -0.013605
# Total intl calls                  -0.012353           0.000305
# Total intl charge                 -0.015180          -0.013630
# Customer service calls            -0.009288          -0.012802
# Churn                              0.035493           0.006141
#
#                         Total night charge  Total intl minutes  \
# Account length                   -0.008960            0.009514
# Area code                        -0.005845           -0.018288
# International plan               -0.028913            0.045871
# Voice mail plan                   0.006064           -0.001318
# Number vmail messages             0.007663            0.002856
# Total day minutes                 0.004300           -0.010155
# Total day calls                   0.022927            0.021565
# Total day charge                  0.004301           -0.010157
# Total eve minutes                -0.012593           -0.011035
# Total eve calls                  -0.002056            0.008703
# Total eve charge                 -0.012601           -0.011043
# Total night minutes               0.999999           -0.015207
# Total night calls                 0.011188           -0.013605
# Total night charge                1.000000           -0.015214
# Total intl minutes               -0.015214            1.000000
# Total intl calls                 -0.012329            0.032304
# Total intl charge                -0.015186            0.999993
# Customer service calls           -0.009277           -0.009640
# Churn                             0.035496            0.068239
#
#                         Total intl calls  Total intl charge  \
# Account length                  0.020661           0.009546
# Area code                      -0.024179          -0.018395
# International plan              0.017366           0.045780
# Voice mail plan                 0.007618          -0.001276
# Number vmail messages           0.013957           0.002884
# Total day minutes               0.008033          -0.010092
# Total day calls                 0.004574           0.021666
# Total day charge                0.008032          -0.010094
# Total eve minutes               0.002541          -0.011067
# Total eve calls                 0.017434           0.008674
# Total eve charge                0.002541          -0.011074
# Total night minutes            -0.012353          -0.015180
# Total night calls               0.000305          -0.013630
# Total night charge             -0.012329          -0.015186
# Total intl minutes              0.032304           0.999993
# Total intl calls                1.000000           0.032372
# Total intl charge               0.032372           1.000000
# Customer service calls         -0.017561          -0.009675
# Churn                          -0.052844           0.068259
#
#                         Customer service calls     Churn
# Account length                       -0.003796  0.016541
# Area code                             0.027572  0.006174
# International plan                   -0.024522  0.259852
# Voice mail plan                      -0.017824 -0.102148
# Number vmail messages                -0.013263 -0.089728
# Total day minutes                    -0.013423  0.205151
# Total day calls                      -0.018942  0.018459
# Total day charge                     -0.013427  0.205151
# Total eve minutes                    -0.012985  0.092796
# Total eve calls                       0.002423  0.009233
# Total eve charge                     -0.012987  0.092786
# Total night minutes                  -0.009288  0.035493
# Total night calls                    -0.012802  0.006141
# Total night charge                   -0.009277  0.035496
# Total intl minutes                   -0.009640  0.068239
# Total intl calls                     -0.017561 -0.052844
# Total intl charge                    -0.009675  0.068259
# Customer service calls                1.000000  0.208750
# Churn                                 0.208750  1.000000

# %% [markdown]
# ..........................................................![image.png](attachment:90ec132f-d6c6-4c35-ac6b-bdb11d1d22ea.png)

# %%
plt.figure(figsize=(12, 6)) # Set the figure size

sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5, fmt='.2f')
# annot - add numbers
plt. title('Correlation Heat Map between Features and Churn')
plt.show()

# %%
# charges are directly proportional to the minutes of conversation - these are dependent variables

# %%
# Describe below which features strongly influence (correlate) 'Churn' answer column

# %%
# Calculate correlation matrix
correlation_matrix = data2.corr()

# Get correlations specifically with 'Churn'
churn_correlation = correlation_matrix['Churn'].sort_values(ascending=False)

# Display the features most strongly correlated with Churn
print("Features that most strongly influence 'Churn':")
print(churn_correlation)
# Out:
# Features that most strongly influence 'Churn':
# Churn                     1.000000
# International plan        0.259852
# Customer service calls    0.208750
# Total day minutes         0.205151
# Total day charge          0.205151
# Total eve minutes         0.092796
# Total eve charge          0.092786
# Total intl charge         0.068259
# Total intl minutes        0.068239
# Total night charge        0.035496
# Total night minutes       0.035493
# Total day calls           0.018459
# Account length            0.016541
# Total eve calls           0.009233
# Area code                 0.006174
# Total night calls         0.006141
# Total intl calls         -0.052844
# Number vmail messages    -0.089728
# Voice mail plan          -0.102148
# Name: Churn, dtype: float64

# %% [markdown]
# # Lab Logbook Requirement:

# %% [markdown]
# <html> <h3 style="font-style:italic; color:blue;">
# 1) Draw a bicolour features interaction diagram between the columns with the numbers of the last and second to last digits of your SID,
# where: </h3> </html>

# %% [markdown]
# ![image.png](attachment:1df500f0-f2fe-435f-bc8e-1c99c1266895.png)

# %% [markdown]
# <html> <h3 style="font-style:italic; color:blue;">
# In case these numbers are the same, then take the next number in order as another column number. For example, if your SID is 2287477, then you plot the bicolour diagram of the 7th and 8th columns. If your SID is 2287499, then the 9th and 0.
#
# 2) Add the code and result to your Lab Logbook.
# </h3> </html>

# %% [markdown]
# <html> <h3 style="color:red;">
# NOTE: DON'T FORGET TO SAVE AND BACK UP YOUR COMPLETED JUPYTER NOTEBOOK AND LAB LOGBOOK ON GITHUB OR ONEDRIVE.
# </h3> </html>

# %%
# Define the features based on SID = 2372330
col1 = 'International plan'
col2 = 'Total eve calls'
# Create the count plot
sns.countplot(data=data, x=col1, hue=col2)
plt.title(f"Count Plot of '{col1}'")
plt.xlabel(col1)
plt.ylabel('Count')
plt.ylim(0, 80)  # Set y-axis limit to 80
plt.show()
